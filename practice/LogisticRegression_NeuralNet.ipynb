# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
df=pd.read_csv("Resources/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# Remove diabetes outcome target from features data
y=df.Outcome
X=df.drop(columns="Outcome")

# %%
# Split training/test datasets
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1,stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler=StandardScaler()

# Fit the StandardScaler
X_scaler=scaler.fit(X_train)
# Scale the data
X_train_scaled=X_scaler.transform(X_train)
X_test_scaled=X_scaler.transform(X_test)

# %%
# Define the logistic regression model
logic_classifier=LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
logic_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred=logic_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.776

# %%
# Define the basic neural network model
nn_model=tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16,activation="relu",input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model=nn_model.fit(X_train_scaled,y_train,epochs=50)

# Evaluate the model using the test data
model_loss,model_accuracy=nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 0s 709us/step - loss: 0.6709 - accuracy: 0.6632
# Epoch 2/50
# 18/18 [==============================] - 0s 580us/step - loss: 0.6374 - accuracy: 0.6649
# Epoch 3/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.6112 - accuracy: 0.6753
# Epoch 4/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5902 - accuracy: 0.6684
# Epoch 5/50
# 18/18 [==============================] - 0s 535us/step - loss: 0.5728 - accuracy: 0.6806
# Epoch 6/50
# 18/18 [==============================] - 0s 554us/step - loss: 0.5588 - accuracy: 0.6858
# Epoch 7/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5467 - accuracy: 0.7101
# Epoch 8/50
# 18/18 [==============================] - 0s 608us/step - loss: 0.5356 - accuracy: 0.7188
# Epoch 9/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5259 - accuracy: 0.7274
# Epoch 10/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.5168 - accuracy: 0.7361
# Epoch 11/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.5086 - accuracy: 0.7413
# Epoch 12/50
# 18/18 [==============================] - 0s 589us/step - loss: 0.5017 - accuracy: 0.7500
# Epoch 13/50
# 18/18 [==============================] - 0s 527us/step - loss: 0.4947 - accuracy: 0.7569
# Epoch 14/50
# 18/18 [==============================] - 0s 589us/step - loss: 0.4885 - accuracy: 0.7552
# Epoch 15/50
# 18/18 [==============================] - 0s 649us/step - loss: 0.4830 - accuracy: 0.7622
# Epoch 16/50
# 18/18 [==============================] - 0s 529us/step - loss: 0.4779 - accuracy: 0.7674
# Epoch 17/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4730 - accuracy: 0.7674
# Epoch 18/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4688 - accuracy: 0.7708
# Epoch 19/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4648 - accuracy: 0.7691
# Epoch 20/50
# 18/18 [==============================] - 0s 529us/step - loss: 0.4608 - accuracy: 0.7708
# Epoch 21/50
# 18/18 [==============================] - 0s 530us/step - loss: 0.4577 - accuracy: 0.7760
# Epoch 22/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4547 - accuracy: 0.7830
# Epoch 23/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4518 - accuracy: 0.7882
# Epoch 24/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4494 - accuracy: 0.7882
# Epoch 25/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4469 - accuracy: 0.7917
# Epoch 26/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4448 - accuracy: 0.7951
# Epoch 27/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4430 - accuracy: 0.7951
# Epoch 28/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4411 - accuracy: 0.7951
# Epoch 29/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4394 - accuracy: 0.7986
# Epoch 30/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4379 - accuracy: 0.7986
# Epoch 31/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4369 - accuracy: 0.7986
# Epoch 32/50
# 18/18 [==============================] - 0s 529us/step - loss: 0.4354 - accuracy: 0.8003
# Epoch 33/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4341 - accuracy: 0.8056
# Epoch 34/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4331 - accuracy: 0.8056
# Epoch 35/50
# 18/18 [==============================] - 0s 471us/step - loss: 0.4325 - accuracy: 0.8056
# Epoch 36/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4314 - accuracy: 0.8056
# Epoch 37/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4304 - accuracy: 0.8038
# Epoch 38/50
# 18/18 [==============================] - 0s 529us/step - loss: 0.4296 - accuracy: 0.8056
# Epoch 39/50
# 18/18 [==============================] - 0s 529us/step - loss: 0.4290 - accuracy: 0.8003
# Epoch 40/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4279 - accuracy: 0.8038
# Epoch 41/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4274 - accuracy: 0.8056
# Epoch 42/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4272 - accuracy: 0.8038
# Epoch 43/50
# 18/18 [==============================] - 0s 589us/step - loss: 0.4260 - accuracy: 0.8056
# Epoch 44/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4257 - accuracy: 0.8021
# Epoch 45/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4250 - accuracy: 0.7986
# Epoch 46/50
# 18/18 [==============================] - 0s 647us/step - loss: 0.4246 - accuracy: 0.8056
# Epoch 47/50
# 18/18 [==============================] - 0s 588us/step - loss: 0.4241 - accuracy: 0.8038
# Epoch 48/50
# 18/18 [==============================] - 0s 589us/step - loss: 0.4235 - accuracy: 0.8056
# Epoch 49/50
# 18/18 [==============================] - 0s 530us/step - loss: 0.4233 - accuracy: 0.8056
# Epoch 50/50
# 18/18 [==============================] - 0s 589us/step - loss: 0.4226 - accuracy: 0.8038
# 6/6 - 0s - loss: 0.5310 - accuracy: 0.7292
# Loss: 0.5309731364250183, Accuracy: 0.7291666865348816
